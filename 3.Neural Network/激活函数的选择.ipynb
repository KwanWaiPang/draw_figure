# %% [markdown]
# # Activation Functions
#
# * 选用kernel learning_dl
# ~~~
# conda activate learning_dl
#
# # conda remove --name learning_dl --all
# # kill -9 +id
# ~~~

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
plt.style.use('./deeplearning.mplstyle')
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.activations import linear, relu, sigmoid
# %matplotlib inline
from matplotlib.widgets import Slider
from lab_utils_common import dlc
from autils import plt_act_trio
from lab_utils_relu import *
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

print("finish import module!!!")
# Out:
# finish import module!!!

# %%
#画出三种激活函数
plt_act_trio()

# %%
_ = plt_relu_ex()

# %% [markdown]
# # 接下来通过实验来看不同激活函数对数据的拟合效果
# [参考链接](https://github.com/kaieye/2022-Machine-Learning-Specialization/blob/main/Advanced%20Learning%20Algorithms/week2/3.Activation%20Functions/C2_W2_Relu.ipynb)
